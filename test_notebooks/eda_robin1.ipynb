# %%
import pandas as pd

df = pd.read_csv("eda.csv")

# adding zip code data
df_zip = pd.read_csv("zip_names.csv")
df2 = df.merge(df_zip, on='zipcode', how='left')

df2.columns
# Out:
# Index(['id', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'date', 'price', 'house_id', 'id.1',
#        'city', 'central_flag'],
#       dtype='object')

# %% [markdown]
# ### Main Questions:
#
# What are the top 10% central properties we sell?
#
# Identify which zip is central?
# Identify which zip is expensive?
# Which properties are the best to hide in?

# %%
# adding price per sqft to the dataframe

df2["price_per_sqft"] = df2["price"] / df2['sqft_above']
df2.head()
# Out:
#            id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  7129300520       3.0       1.00       1180.0    5650.0     1.0         NaN
# 1  7129300520       3.0       1.00       1180.0    5650.0     1.0         NaN
# 2  6414100192       3.0       2.25       2570.0    7242.0     2.0         0.0
# 3  5631500400       2.0       1.00        770.0   10000.0     1.0         0.0
# 4  5631500400       2.0       1.00        770.0   10000.0     1.0         0.0
#
#    view  condition  grade  ...     long  sqft_living15  sqft_lot15  \
# 0   0.0          3      7  ... -122.257         1340.0      5650.0
# 1   0.0          3      7  ... -122.257         1340.0      5650.0
# 2   0.0          3      7  ... -122.319         1690.0      7639.0
# 3   0.0          3      6  ... -122.233         2720.0      8062.0
# 4   0.0          3      6  ... -122.233         2720.0      8062.0
#
#          date     price    house_id  id.1     city  central_flag  \
# ...

# %%
df3 = df[df.duplicated('id', keep=False)].groupby('id')['date'].max().reset_index()
df3[df3["id"] == 6300000226]

# 4139480200 - 2014-12-09
# 6300000226 - 2015-05-04
# Out:
#              id        date
# 118  6300000226  2015-05-04
